# %% [markdown]
# # Convolutional Neural Networks
#
# ## Project: Write an Algorithm for Landmark Classification
#
#
# ### Introduction
#
# The project folder has the following structure:
#
# * In the main directory you have this notebook, `cnn_from_scratch.ipynb`, that contains the instruction and some questions you will have to answer. Follow this notebook and complete the required sections in order.
#
# * In the `src/` directory you have several source files. As instructed in this notebook, you will open and complete those files, then come back to this notebook to execute some tests that will verify what you have done. While these tests don't guarantee that your work is bug-free, they will help you finding the most obvious problems so you will be able to proceed to the next step with confidence.
#
# * Sometimes you will need to restart the notebook. If you do so, remember to execute also the cells containing the code you have already completed starting from the top, before you move on.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# > <img src="static_images/icons/noun-info-2558213.png" alt="?" style="width:25px"/> Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut.  Markdown cells can be edited by double-clicking the cell to enter edit mode.
#
# The rubric contains _optional_ "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. If you decide to pursue the "Stand Out Suggestions", you should include the code in this Jupyter notebook.
#
# ### Designing and training a CNN from scratch
#
# In this notebook, you will create a CNN that classifies landmarks.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 50%.
#
# Although 50% may seem low at first glance, it seems more reasonable after realizing how difficult of a problem this is. Many times, an image that is taken at a landmark captures a fairly mundane image of an animal or plant, like in the following picture.
#
# <img src="static_images/train/00.Haleakala_National_Park/084c2aa50d0a9249.jpg" alt="Bird in Haleakalā National Park" style="width: 400px;"/>
#
# Just by looking at that image alone, would you have been able to guess that it was taken at the Haleakalā National Park in Hawaii?
#
# An accuracy of 50% is significantly better than random guessing, which would provide an accuracy of just 2% (100% / 50 classes). In Step 2 of this notebook, you will have the opportunity to greatly improve accuracy by using transfer learning to create a CNN.
#
# Experiment with different architectures, hyperparameters, training strategies, and trust your intuition.  And, of course, have fun!
#
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 0: Setting up
#
# The following cells make sure that your environment is setup correctly, download the data if you don't have it already, and also check that your GPU is available and ready to go. You have to execute them every time you restart your notebook.

# %%
# Install requirements
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: opencv-python-headless==4.5.3.56 in c:\vishnu conda\envs\udacity\lib\site-packages (from -r requirements.txt (line 1)) (4.5.3.56)
# Requirement already satisfied: matplotlib==3.4.3 in c:\vishnu conda\envs\udacity\lib\site-packages (from -r requirements.txt (line 2)) (3.4.3)
# Requirement already satisfied: numpy==1.21.2 in c:\vishnu conda\envs\udacity\lib\site-packages (from -r requirements.txt (line 3)) (1.21.2)
# Requirement already satisfied: pillow==7.0.0 in c:\vishnu conda\envs\udacity\lib\site-packages (from -r requirements.txt (line 4)) (7.0.0)
# Requirement already satisfied: bokeh==2.1.1 in c:\vishnu conda\envs\udacity\lib\site-packages (from -r requirements.txt (line 5)) (2.1.1)
# Requirement already satisfied: torch==1.11.0 in c:\vishnu conda\envs\udacity\lib\site-packages (from -r requirements.txt (line 6)) (1.11.0)
# Requirement already satisfied: torchvision==0.12.0 in c:\vishnu conda\envs\udacity\lib\site-packages (from -r requirements.txt (line 7)) (0.12.0)
# Requirement already satisfied: tqdm==4.63.0 in c:\vishnu conda\envs\udacity\lib\site-packages (from -r requirements.txt (line 8)) (4.63.0)
# Requirement already satisfied: ipywidgets==7.6.5 in c:\vishnu conda\envs\udacity\lib\site-packages (from -r requirements.txt (line 9)) (7.6.5)
# Requirement already satisfied: livelossplot==0.5.4 in c:\vishnu conda\envs\udacity\lib\site-packages (from -r requirements.txt (line 10)) (0.5.4)
# Requirement already satisfied: pytest==7.1.1 in c:\vishnu conda\envs\udacity\lib\site-packages (from -r requirements.txt (line 11)) (7.1.1)
# Requirement already satisfied: pandas==1.3.5 in c:\vishnu conda\envs\udacity\lib\site-packages (from -r requirements.txt (line 12)) (1.3.5)
# Requirement already satisfied: seaborn==0.11.2 in c:\vishnu conda\envs\udacity\lib\site-packages (from -r requirements.txt (line 13)) (0.11.2)
# Requirement already satisfied: cycler>=0.10 in c:\vishnu conda\envs\udacity\lib\site-packages (from matplotlib==3.4.3->-r requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\vishnu conda\envs\udacity\lib\site-packages (from matplotlib==3.4.3->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\vishnu conda\envs\udacity\lib\site-packages (from matplotlib==3.4.3->-r requirements.txt (line 2)) (3.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\vishnu conda\envs\udacity\lib\site-packages (from matplotlib==3.4.3->-r requirements.txt (line 2)) (1.4.4)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\vishnu conda\envs\udacity\lib\site-packages (from bokeh==2.1.1->-r requirements.txt (line 5)) (4.4.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\vishnu conda\envs\udacity\lib\site-packages (from bokeh==2.1.1->-r requirements.txt (line 5)) (6.0.1)
# Requirement already satisfied: Jinja2>=2.7 in c:\vishnu conda\envs\udacity\lib\site-packages (from bokeh==2.1.1->-r requirements.txt (line 5)) (3.1.2)
# Requirement already satisfied: tornado>=5.1 in c:\vishnu conda\envs\udacity\lib\site-packages (from bokeh==2.1.1->-r requirements.txt (line 5)) (6.2)
# Requirement already satisfied: packaging>=16.8 in c:\vishnu conda\envs\udacity\lib\site-packages (from bokeh==2.1.1->-r requirements.txt (line 5)) (23.1)
# Requirement already satisfied: requests in c:\vishnu conda\envs\udacity\lib\site-packages (from torchvision==0.12.0->-r requirements.txt (line 7)) (2.28.1)
# Requirement already satisfied: colorama in c:\vishnu conda\envs\udacity\lib\site-packages (from tqdm==4.63.0->-r requirements.txt (line 8)) (0.4.6)
# Requirement already satisfied: nbformat>=4.2.0 in c:\vishnu conda\envs\udacity\lib\site-packages (from ipywidgets==7.6.5->-r requirements.txt (line 9)) (5.8.0)
# Requirement already satisfied: ipython>=4.0.0 in c:\vishnu conda\envs\udacity\lib\site-packages (from ipywidgets==7.6.5->-r requirements.txt (line 9)) (7.34.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\vishnu conda\envs\udacity\lib\site-packages (from ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\vishnu conda\envs\udacity\lib\site-packages (from ipywidgets==7.6.5->-r requirements.txt (line 9)) (6.16.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\vishnu conda\envs\udacity\lib\site-packages (from ipywidgets==7.6.5->-r requirements.txt (line 9)) (3.0.8)
# Requirement already satisfied: traitlets>=4.3.1 in c:\vishnu conda\envs\udacity\lib\site-packages (from ipywidgets==7.6.5->-r requirements.txt (line 9)) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\vishnu conda\envs\udacity\lib\site-packages (from ipywidgets==7.6.5->-r requirements.txt (line 9)) (3.5.2)
# Requirement already satisfied: py>=1.8.2 in c:\vishnu conda\envs\udacity\lib\site-packages (from pytest==7.1.1->-r requirements.txt (line 11)) (1.11.0)
# Requirement already satisfied: tomli>=1.0.0 in c:\vishnu conda\envs\udacity\lib\site-packages (from pytest==7.1.1->-r requirements.txt (line 11)) (2.0.1)
# Requirement already satisfied: atomicwrites>=1.0 in c:\vishnu conda\envs\udacity\lib\site-packages (from pytest==7.1.1->-r requirements.txt (line 11)) (1.4.1)
# Requirement already satisfied: importlib-metadata>=0.12 in c:\vishnu conda\envs\udacity\lib\site-packages (from pytest==7.1.1->-r requirements.txt (line 11)) (6.7.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\vishnu conda\envs\udacity\lib\site-packages (from pytest==7.1.1->-r requirements.txt (line 11)) (23.1.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\vishnu conda\envs\udacity\lib\site-packages (from pytest==7.1.1->-r requirements.txt (line 11)) (1.2.0)
# Requirement already satisfied: iniconfig in c:\vishnu conda\envs\udacity\lib\site-packages (from pytest==7.1.1->-r requirements.txt (line 11)) (2.0.0)
# Requirement already satisfied: pytz>=2017.3 in c:\vishnu conda\envs\udacity\lib\site-packages (from pandas==1.3.5->-r requirements.txt (line 12)) (2023.3)
# Requirement already satisfied: scipy>=1.0 in c:\vishnu conda\envs\udacity\lib\site-packages (from seaborn==0.11.2->-r requirements.txt (line 13)) (1.7.3)
# Requirement already satisfied: zipp>=0.5 in c:\vishnu conda\envs\udacity\lib\site-packages (from importlib-metadata>=0.12->pytest==7.1.1->-r requirements.txt (line 11)) (3.15.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\vishnu conda\envs\udacity\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5->-r requirements.txt (line 9)) (7.4.9)
# Requirement already satisfied: pyzmq>=17 in c:\vishnu conda\envs\udacity\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5->-r requirements.txt (line 9)) (24.0.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\vishnu conda\envs\udacity\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\vishnu conda\envs\udacity\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.5.7)
# Requirement already satisfied: psutil in c:\vishnu conda\envs\udacity\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5->-r requirements.txt (line 9)) (5.9.5)
# Requirement already satisfied: debugpy>=1.0 in c:\vishnu conda\envs\udacity\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.6.7)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\vishnu conda\envs\udacity\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (3.0.39)
# Requirement already satisfied: pickleshare in c:\vishnu conda\envs\udacity\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.7.5)
# Requirement already satisfied: backcall in c:\vishnu conda\envs\udacity\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.2.0)
# Requirement already satisfied: pygments in c:\vishnu conda\envs\udacity\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (2.15.1)
# Requirement already satisfied: setuptools>=18.5 in c:\vishnu conda\envs\udacity\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (65.6.3)
# Requirement already satisfied: decorator in c:\vishnu conda\envs\udacity\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\vishnu conda\envs\udacity\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.19.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\vishnu conda\envs\udacity\lib\site-packages (from Jinja2>=2.7->bokeh==2.1.1->-r requirements.txt (line 5)) (2.1.3)
# Requirement already satisfied: jupyter-core in c:\vishnu conda\envs\udacity\lib\site-packages (from nbformat>=4.2.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (4.12.0)
# Requirement already satisfied: fastjsonschema in c:\vishnu conda\envs\udacity\lib\site-packages (from nbformat>=4.2.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (2.18.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\vishnu conda\envs\udacity\lib\site-packages (from nbformat>=4.2.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (4.17.3)
# Requirement already satisfied: six>=1.5 in c:\vishnu conda\envs\udacity\lib\site-packages (from python-dateutil>=2.7->matplotlib==3.4.3->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\vishnu conda\envs\udacity\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (6.5.5)
# Requirement already satisfied: idna<4,>=2.5 in c:\vishnu conda\envs\udacity\lib\site-packages (from requests->torchvision==0.12.0->-r requirements.txt (line 7)) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\vishnu conda\envs\udacity\lib\site-packages (from requests->torchvision==0.12.0->-r requirements.txt (line 7)) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\vishnu conda\envs\udacity\lib\site-packages (from requests->torchvision==0.12.0->-r requirements.txt (line 7)) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\vishnu conda\envs\udacity\lib\site-packages (from requests->torchvision==0.12.0->-r requirements.txt (line 7)) (1.26.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\vishnu conda\envs\udacity\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.8.3)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in c:\vishnu conda\envs\udacity\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.3.10)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\vishnu conda\envs\udacity\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (5.12.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\vishnu conda\envs\udacity\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.19.3)
# Requirement already satisfied: entrypoints in c:\vishnu conda\envs\udacity\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.4)
# Requirement already satisfied: pywin32>=1.0 in c:\vishnu conda\envs\udacity\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (306)
# Requirement already satisfied: terminado>=0.8.3 in c:\vishnu conda\envs\udacity\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.17.1)
# Requirement already satisfied: nbconvert>=5 in c:\vishnu conda\envs\udacity\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (7.6.0)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\vishnu conda\envs\udacity\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.0.0)
# Requirement already satisfied: prometheus-client in c:\vishnu conda\envs\udacity\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.17.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\vishnu conda\envs\udacity\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.8.2)
# Requirement already satisfied: argon2-cffi in c:\vishnu conda\envs\udacity\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (21.3.0)
# Requirement already satisfied: wcwidth in c:\vishnu conda\envs\udacity\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.2.6)
# Requirement already satisfied: notebook-shim>=0.2.3 in c:\vishnu conda\envs\udacity\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.2.3)
# Requirement already satisfied: jupyter-server>=1.8 in c:\vishnu conda\envs\udacity\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.24.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\vishnu conda\envs\udacity\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (3.0.1)
# Requirement already satisfied: jupyterlab-pygments in c:\vishnu conda\envs\udacity\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.2.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\vishnu conda\envs\udacity\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (6.0.0)
# Requirement already satisfied: defusedxml in c:\vishnu conda\envs\udacity\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\vishnu conda\envs\udacity\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\vishnu conda\envs\udacity\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.2.1)
# Requirement already satisfied: beautifulsoup4 in c:\vishnu conda\envs\udacity\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (4.12.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\vishnu conda\envs\udacity\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.7.4)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\vishnu conda\envs\udacity\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\vishnu conda\envs\udacity\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (21.2.0)
# Requirement already satisfied: webencodings in c:\vishnu conda\envs\udacity\lib\site-packages (from bleach!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.5.1)
# Requirement already satisfied: websocket-client in c:\vishnu conda\envs\udacity\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.6.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\vishnu conda\envs\udacity\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (3.7.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\vishnu conda\envs\udacity\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\vishnu conda\envs\udacity\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (2.4.1)
# Requirement already satisfied: sniffio>=1.1 in c:\vishnu conda\envs\udacity\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: exceptiongroup in c:\vishnu conda\envs\udacity\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.1.2)
# Requirement already satisfied: pycparser in c:\vishnu conda\envs\udacity\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (2.21)

# %%
from src.helpers import setup_env

# If running locally, this will download dataset (make sure you have at 
# least 2 Gb of space on your hard drive)
setup_env()
# Out:
# GPU *NOT* available. Will use CPU (slow)
# Dataset already downloaded. If you need to re-download, please delete the directory landmark_images
# Reusing cached mean and std

# %% [markdown]
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 1: Data
#
# In this and the following steps we are going to complete some code, and then execute some tests to make sure the code works as intended.
#
# Open the file `src/data.py`. It contains a function called `get_data_loaders`. Read the function and complete all the parts marked by `YOUR CODE HERE`. Once you have finished, test that your implementation is correct by executing the following cell (see below for what to do if a test fails):

# %%
# !pytest -vv src/data.py -k data_loaders
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.7.6, pytest-7.1.1, pluggy-1.2.0 -- C:\Vishnu Conda\envs\udacity\python.exe
# cachedir: .pytest_cache
# rootdir: F:\Udacity_Project
# plugins: anyio-3.7.1
# collecting ... collected 4 items / 1 deselected / 3 selected
#
# src/data.py::test_data_loaders_keys PASSED                               [ 33%]
# src/data.py::test_data_loaders_output_type PASSED                        [ 66%]
# src/data.py::test_data_loaders_output_shape PASSED                       [100%]
#
# ============================== warnings summary ===============================
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
#   C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if LooseVersion(module.__version__) < minver:
#
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
#   C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     other = LooseVersion(other)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ================ 3 passed, 1 deselected, 10 warnings in 1.72s =================

# %% [markdown]
# You should see something like:
# ```
# src/data.py::test_data_loaders_keys PASSED                               [ 33%]
# src/data.py::test_data_loaders_output_type PASSED                        [ 66%]
# src/data.py::test_data_loaders_output_shape PASSED                       [100%]
#
# ======================= 3 passed, 1 deselected in 1.81s ========================
# ```
# If all the tests are `PASSED`, you can move to the next section.
#
# > <img src="static_images/icons/noun-info-2558213.png" alt="?" style="width:25px"/> **What to do if tests fail**
# When a test fails, `pytest` will mark it as `FAILED` as opposed to `PASSED`, and will print a lot of useful output, including a message that should tell you what the problem is. For example, this is the output of a failed test:
# > ```
# >    def test_data_loaders_keys(data_loaders):
# >
# >       assert set(data_loaders.keys()) == {"train", "valid", "test"}
# E       AssertionError: assert {'tes', 'train', 'valid'} == {'test', 'train', 'valid'}
# E         Extra items in the left set:
# E         'tes'
# E         Full diff:
# E         - {'test', 'train', 'valid'}
# E         + {'tes', 'train', 'valid'}
# E         ?                          +++++++
# >
# > src/data.py:171: AssertionError
# -------------- Captured stdout setup ----------------------------------------------
# Reusing cached mean and std for landmark_images
# Dataset mean: tensor([0.4638, 0.4725, 0.4687]), std: tensor([0.2699, 0.2706, 0.3018])
# =========== short test summary info ===============================================
# FAILED src/data.py::test_data_loaders_keys - AssertionError: The keys of the data_loaders dictionary should be train, valid and test
# > ```
# > In the `short test summary info` you can see a short description of the problem. In this case, the dictionary we are returning has the wrong keys. Going above a little, you can see that the test expects `{'test', 'train', 'valid'}` while we are returning `{'tes', 'train', 'valid'}` (there is a missing `t`). So we can go back to our function, fix that problem and test again.
# >
# > In other cases, you might get an error like:
# > ```
#     def _conv_forward(self, input: Tensor, weight: Tensor, bias: Optional[Tensor]):
#         if self.padding_mode != 'zeros':
#             return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#                             weight, bias, self.stride,
#                             _pair(0), self.dilation, self.groups)
#         return F.conv2d(input, weight, bias, self.stride,
# >                       self.padding, self.dilation, self.groups)
# E       RuntimeError: Input type (torch.cuda.FloatTensor) and weight type (torch.FloatTensor) should be the same
# >
# > ../../../../miniconda3/envs/udacity_starter/lib/python3.7/site-packages/torch/nn/modules/conv.py:440: RuntimeError
# > ```
# > Looking at the stack trace you should be able to understand what it is going on. In this case, we forgot to add a `.cuda()` to some tensor. For example, the model is on the GPU, but the data aren't.

# %% [markdown]
# <img src="static_images/icons/noun-question-mark-869751.png" alt="?" style="width:25px"/> **Question:** Describe your chosen procedure for preprocessing the data.
# - How does your code resize the images (by cropping, stretching, etc)?  What size did you pick for the input tensor, and why?
# - Did you decide to augment the dataset?  If so, how (through translations, flips, rotations, etc)?  If not, why not?

# %% [markdown]
# <img src="static_images/icons/noun-answer-3361020.png" alt=">" style="width:25px"/> **Answer**: My code first resizes the image to 256 and then crops to 224. I picked 224 as the input size because it is the recommended input size for using pytorch's pre-trained models. I did decide to augment the dataset via RandAugment, a typical set of augmentations for natural images. I added this augmentation with the goal of improving my model's robustness, thus improving test accuracy.

# %% [markdown]
# ### Visualize a Batch of Training Data
#
# Go back to `src/data.py` and complete the function `visualize_one_batch` in all places with the `YOUR CODE HERE` marker. After you're done, execute the following cell and make sure the test `src/data.py::test_visualize_one_batch` is `PASSED`:

# %%
# !pytest -vv src/data.py -k visualize_one_batch
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.7.6, pytest-7.1.1, pluggy-1.2.0 -- C:\Vishnu Conda\envs\udacity\python.exe
# cachedir: .pytest_cache
# rootdir: F:\Udacity_Project
# plugins: anyio-3.7.1
# collecting ... collected 4 items / 3 deselected / 1 selected
#
# src/data.py::test_visualize_one_batch PASSED                             [100%]
#
# ============================== warnings summary ===============================
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
#   C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if LooseVersion(module.__version__) < minver:
#
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
#   C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     other = LooseVersion(other)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ================ 1 passed, 3 deselected, 10 warnings in 1.31s =================

# %%
# %matplotlib inline
from src.data import visualize_one_batch, get_data_loaders

# use get_data_loaders to get the data_loaders dictionary.
# Use a batch_size of 5, a validation size of 0.01, and num_workers=-1 (all CPUs)
data_loaders = get_data_loaders(batch_size=5, valid_size=0.01, num_workers=-1)

visualize_one_batch(data_loaders)
# Out:
# Reusing cached mean and std
# Dataset mean: tensor([0.4638, 0.4725, 0.4687]), std: tensor([0.2697, 0.2706, 0.3017])
# Reusing cached mean and std

# %% [markdown]
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 2: Define model
#
# Open `src/model.py` and complete the `MyModel` class filling in all the `YOUR CODE HERE` sections. After you're done, execute the following test and make sure it passes:

# %%
# !pytest -vv src/model.py
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.7.6, pytest-7.1.1, pluggy-1.2.0 -- C:\Vishnu Conda\envs\udacity\python.exe
# cachedir: .pytest_cache
# rootdir: F:\Udacity_Project
# plugins: anyio-3.7.1
# collecting ... collected 1 item
#
# src/model.py::test_model_construction PASSED                             [100%]
#
# ============================== warnings summary ===============================
# src/model.py::test_model_construction
# src/model.py::test_model_construction
# src/model.py::test_model_construction
# src/model.py::test_model_construction
# src/model.py::test_model_construction
#   C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if LooseVersion(module.__version__) < minver:
#
# src/model.py::test_model_construction
# src/model.py::test_model_construction
# src/model.py::test_model_construction
# src/model.py::test_model_construction
# src/model.py::test_model_construction
#   C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     other = LooseVersion(other)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ======================= 1 passed, 10 warnings in 7.08s ========================

# %% [markdown]
# <img src="static_images/icons/noun-question-mark-869751.png" alt="?" style="width:25px"/> **Question**: Outline the steps you took to get to your final CNN architecture and your reasoning at each step.

# %% [markdown]
# <img src="static_images/icons/noun-answer-3361020.png" alt=">" style="width:25px"/> __Answer:__ I decided to use 5 convolutional layers so that my model could be sufficiently expressive. I used dropout layers to reduce my model's tendency to overfit the training data. I made my model output a 50-dimensional vector to match with the 50 available landmark classes.

# %% [markdown]
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 3: define loss and optimizer
#
# Open `src/optimization.py` and complete the `get_loss` function, then execute the test and make sure it passes:

# %%
# !pytest -vv src/optimization.py -k get_loss
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.7.6, pytest-7.1.1, pluggy-1.2.0 -- C:\Vishnu Conda\envs\udacity\python.exe
# cachedir: .pytest_cache
# rootdir: F:\Udacity_Project
# plugins: anyio-3.7.1
# collecting ... collected 7 items / 6 deselected / 1 selected
#
# src/optimization.py::test_get_loss PASSED                                [100%]
#
# ======================= 1 passed, 6 deselected in 0.61s =======================

# %% [markdown]
# Then, in the same file, complete the `get_optimizer` function then execute its tests, and make sure they all pass:

# %%
# !pytest -vv src/optimization.py -k get_optimizer
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.7.6, pytest-7.1.1, pluggy-1.2.0 -- C:\Vishnu Conda\envs\udacity\python.exe
# cachedir: .pytest_cache
# rootdir: F:\Udacity_Project
# plugins: anyio-3.7.1
# collecting ... collected 7 items / 1 deselected / 6 selected
#
# src/optimization.py::test_get_optimizer_type PASSED                      [ 16%]
# src/optimization.py::test_get_optimizer_is_linked_with_model PASSED      [ 33%]
# src/optimization.py::test_get_optimizer_returns_adam PASSED              [ 50%]
# src/optimization.py::test_get_optimizer_sets_learning_rate PASSED        [ 66%]
# src/optimization.py::test_get_optimizer_sets_momentum PASSED             [ 83%]
# src/optimization.py::test_get_optimizer_sets_weight_decat PASSED         [100%]
#
# ======================= 6 passed, 1 deselected in 0.53s =======================

# %% [markdown]
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 4: Train and Validate the Model
#
# > <img src="static_images/icons/noun-info-2558213.png" alt="?" style="width:25px"/> Testing ML code is notoriously difficult. The tests in this section merely exercise the functions you are completing, so it will help you catching glaring problems but it won't guarantee that your training code is bug-free. If you see that your loss is not decreasing, for example, that's a sign of a bug or of a flawed model design. Use your judgement.
#
# Open `src/train.py` and complete the `train_one_epoch` function, then run the tests:

# %%
# !pytest -vv src/train.py -k train_one_epoch
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.7.6, pytest-7.1.1, pluggy-1.2.0 -- C:\Vishnu Conda\envs\udacity\python.exe
# cachedir: .pytest_cache
# rootdir: F:\Udacity_Project
# plugins: anyio-3.7.1
# collecting ... collected 4 items / 3 deselected / 1 selected
#
# src/train.py::test_train_one_epoch PASSED                                [100%]
#
# ============================== warnings summary ===============================
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
#   C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if LooseVersion(module.__version__) < minver:
#
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
#   C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     other = LooseVersion(other)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ================ 1 passed, 3 deselected, 10 warnings in 14.20s ================

# %% [markdown]
# Now complete the `valid` function, then run the tests:

# %%
# !pytest -vv src/train.py -k valid_one_epoch
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.7.6, pytest-7.1.1, pluggy-1.2.0 -- C:\Vishnu Conda\envs\udacity\python.exe
# cachedir: .pytest_cache
# rootdir: F:\Udacity_Project
# plugins: anyio-3.7.1
# collecting ... collected 4 items / 3 deselected / 1 selected
#
# src/train.py::test_valid_one_epoch PASSED                                [100%]
#
# ============================== warnings summary ===============================
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
#   C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if LooseVersion(module.__version__) < minver:
#
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
#   C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     other = LooseVersion(other)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ================ 1 passed, 3 deselected, 10 warnings in 7.34s =================

# %% [markdown]
# Now complete the `optimize` function, then run the tests:

# %%
# !pytest -vv src/train.py -k optimize
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.7.6, pytest-7.1.1, pluggy-1.2.0 -- C:\Vishnu Conda\envs\udacity\python.exe
# cachedir: .pytest_cache
# rootdir: F:\Udacity_Project
# plugins: anyio-3.7.1
# collecting ... collected 4 items / 3 deselected / 1 selected
#
# src/train.py::test_optimize PASSED                                       [100%]
#
# ============================== warnings summary ===============================
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
#   C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if LooseVersion(module.__version__) < minver:
#
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
#   C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     other = LooseVersion(other)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ================ 1 passed, 3 deselected, 10 warnings in 23.69s ================

# %% [markdown]
# Finally, complete the `test` function then run the tests:

# %%
# !pytest -vv src/train.py -k one_epoch_test
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.7.6, pytest-7.1.1, pluggy-1.2.0 -- C:\Vishnu Conda\envs\udacity\python.exe
# cachedir: .pytest_cache
# rootdir: F:\Udacity_Project
# plugins: anyio-3.7.1
# collecting ... collected 4 items / 3 deselected / 1 selected
#
# src/train.py::test_one_epoch_test PASSED                                 [100%]
#
# ============================== warnings summary ===============================
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
#   C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if LooseVersion(module.__version__) < minver:
#
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
#   C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     other = LooseVersion(other)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ================ 1 passed, 3 deselected, 10 warnings in 7.51s =================

# %% [markdown]
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 5: Putting everything together
#
# Allright, good job getting here! Now it's time to see if all our hard work pays off. In the following cell we will train your model and validate it against the validation set.
#
# Let's start by defining a few hyperparameters. Feel free to experiment with different values and try to optimize your model:

# %%
# !pytest -vv src/predictor.py
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.7.6, pytest-7.1.1, pluggy-1.2.0 -- C:\Vishnu Conda\envs\udacity\python.exe
# cachedir: .pytest_cache
# rootdir: F:\Udacity_Project
# plugins: anyio-3.7.1
# collecting ... collected 1 item
#
# src/predictor.py::test_model_construction PASSED                         [100%]
#
# ============================== warnings summary ===============================
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
# C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152
#   C:\Vishnu Conda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if LooseVersion(module.__version__) < minver:
#
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
# C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346
#   C:\Vishnu Conda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     other = LooseVersion(other)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ======================= 1 passed, 10 warnings in 7.39s ========================

# %% [markdown]
# Please check the "testing_environment.ipynb" notebook as the model was trained in a separate GPU environment as the udacity workspace is showing a gpu error and the Udacity technical support suggested this idea. sompls check the the notebook as all the other steps have been completed there.
